# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a799c97b-0cc9-4b56-979a-eebaddf1babe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a799c97b-0cc9-4b56-979a-eebaddf1babe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

# Path to the uploaded zip file (it will be in the current working directory)
zip_file = "Code4ML.zip"  # Change this to the name of your uploaded zip file

# Unzip the file
with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall("/content/")  # Extract to the root directory of Colab

# Verify that the folder has been extracted
os.listdir("/content/Code4ML")  # Change 'your_folder' to the actual folder name
# Out:
# ['data', 'svm_train.py', 'common']

# %%
# !pip install scikit-learn optuna pandas numpy cloudpickle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 20.2 MB/s eta 0:00:00
# ...

# %%
# !python /content/Code4ML/svm_train.py 1 /content/Code4ML/data/markup_data.csv 50
# Out:
# Index(['Unnamed: 0', 'code_block', 'too_long', 'marks', 'graph_vertex_id'], dtype='object')
# loaded
# Selecting hyperparameters
# [I 2025-05-03 08:26:42,265] A new study created in memory with name: svm with kernels
# A new study created in memory with name: svm with kernels
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [I 2025-05-03 08:28:02,091] Trial 0 finished with value: 0.6553011439717518 and parameters: {'tfidf__min_df': 8, 'tfidf__max_df': 0.6718389519258763, 'svm__C': 183.8854665714301, 'svm__kernel': 'linear'}. Best is trial 0 with value: 0.6553011439717518.
# Trial 0 finished with value: 0.6553011439717518 and parameters: {'tfidf__min_df': 8, 'tfidf__max_df': 0.6718389519258763, 'svm__C': 183.8854665714301, 'svm__kernel': 'linear'}. Best is trial 0 with value: 0.6553011439717518.
# ...
